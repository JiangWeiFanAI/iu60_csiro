# %%
import os
import data_processing_tool as dpt
from datetime import timedelta, date, datetime
# from args_parameter import args
from PrepareData import ACCESS_BARRA_v4
from torch.utils.data import Dataset,random_split
import torch,os,torchvision
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader,random_split
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim

# from PIL import Image
import time
from sklearn.model_selection import StratifiedShuffleSplit
# import model
# from model import my_model
# import utility
from tqdm import tqdm
import math
from skimage.measure import compare_ssim
from skimage.measure import compare_psnr,compare_mse
import platform
from torch.autograd import Variable
import argparse
def set_args():
    parser = argparse.ArgumentParser(description='BARRA_R and ACCESS-S!')
    parser.add_argument('--args_test', type=int, default=0,
                            help='testing parameters input')
    parser.add_argument('--debug', action='store_true',
                        help='Enables debug mode')
    parser.add_argument('--template', default='.',
                        help='You can set various templates in option.py')

    # Hardware specifications
    parser.add_argument('--n_threads', type=int, default=0,
                        help='number of threads for data loading')
    parser.add_argument('--cpu', action='store_true',
                        help='use cpu only')
    parser.add_argument('--n_GPUs', type=int, default=1,
                        help='number of GPUs')
    parser.add_argument('--seed', type=int, default=1,
                        help='random seed')

    # Data specifications
    parser.add_argument('--pr', type=bool, 
                    default=True,
                    help='add-on pr?')

    parser.add_argument('--dem', type=bool, 
                    default=True,
                    help='add-on dem?') 
    parser.add_argument('--psl', type=bool, 
                    default=False,
                    help='add-on psl?') 
    parser.add_argument('--zg', type=bool, 
                    default=False,
                    help='add-on zg?') 
    parser.add_argument('--tasmax', type=bool, 
                    default=False,
                    help='add-on tasmax?') 
    parser.add_argument('--tasmin', type=bool, 
                    default=False,
                    help='add-on tasmin?')

    parser.add_argument('--leading_time_we_use', type=int, 
                    default=7,
                    help='add-on tasmin?')




    parser.add_argument('--ensemble', type=int, 
                    default=2,
                    help='total ensambles is 11') 


    parser.add_argument('--channels', type=float, 
                        default=0,
                        help='channel of data_input must') 
    #[111.85, 155.875, -44.35, -9.975]
    parser.add_argument('--domain', type=list, 
                        default=[112.9, 154.25, -43.7425, -9.0],
                        help='dataset directory')    


    parser.add_argument('--file_ACCESS_dir', type=str, 
                        default="F:/climate/access-s1/pr/daily/",

                        help='dataset directory')
    parser.add_argument('--file_BARRA_dir', type=str, 
                        default="C:/Users/JIA059/barra/",
                        help='dataset directory')

    parser.add_argument('--file_DEM_dir', type=str, 
                        default="../DEM/",
                        help='dataset directory')

#     parser.add_argument('--nine2nine', type=bool, 
#                         default=True,
#                         help='whether rainfall acculate from 9am to 9am')
#     parser.add_argument('--date_minus_one', type=int, 
#                         default=1,
#                         help='whether rainfall acculate from yesterday(1)/today(0) 9am to tody/tomorrow 9am')


    parser.add_argument('--dir_demo', type=str, default='../test',
                        help='demo image directory')
    #     parser.add_argument('--data_train', type=str, default='BARRA_R',
    #                         help='train dataset name')
    #     parser.add_argument('--data_test', type=str, default='DIV2K',
    #                         help='test dataset name')
    parser.add_argument('--benchmark_noise', action='store_true',
                        help='use noisy benchmark sets')
    parser.add_argument('--n_train', type=int, default=800,
                        help='number of training set')
    parser.add_argument('--n_val', type=int, default=10,
                        help='number of validation set')
    parser.add_argument('--offset_val', type=int, default=800,
                        help='validation index offest')
    parser.add_argument('--ext', type=str, default='sep',
                        help='dataset file extension')
    parser.add_argument('--scale', default='4',
                        help='super resolution scale')
    parser.add_argument('--patch_size', type=int, default=96,
                        help='output patch size')
    #??????????????????????????????????????????????????
    parser.add_argument('--rgb_range', type=int, default=400,
                        help='maximum value of RGB')
    parser.add_argument('--n_colors', type=int, default=1,
                        help='number of color channels to use')
    parser.add_argument('--noise', type=str, default='.',
                        help='Gaussian noise std.')
    parser.add_argument('--chop', action='store_true',
                        help='enable memory-efficient forward')

    # Model specifications
    parser.add_argument('--model', default='RCAN',
                        help='model name')

    parser.add_argument('--act', type=str, default='relu',
                        help='activation function')
    parser.add_argument('--pre_train', type=str, default='./model/RCAN_BIX4.pt',
                        help='pre-trained model directory')
    parser.add_argument('--extend', type=str, default='.',
                        help='pre-trained model directory')
    parser.add_argument('--n_resblocks', type=int, default=16,
                        help='number of residual blocks')
    parser.add_argument('--n_feats', type=int, default=64,
                        help='number of feature maps')
    parser.add_argument('--res_scale', type=float, default=1,
                        help='residual scaling')
    parser.add_argument('--shift_mean', default=True,
                        help='subtract pixel mean from the input')
    parser.add_argument('--precision', type=str, default='single',
                        choices=('single', 'half'),
                        help='FP precision for test (single | half)')

    # Training specifications

    parser.add_argument('--train_name', type=str, default='temp01',
                        help='the trainning name of the set')
    parser.add_argument('--reset', action='store_true',
                        help='reset the training')
    parser.add_argument('--test_every', type=int, default=1000,
                        help='do test per every N batches')
    parser.add_argument('--epochs', type=int, default=300,
                        help='number of epochs to train')
    parser.add_argument('--batch_size', type=int, default=32,
                        help='input batch size for training')
    parser.add_argument('--split_batch', type=int, default=1,
                        help='split the batch into smaller chunks')
    parser.add_argument('--self_ensemble', action='store_true',
                        help='use self-ensemble method for test')
    parser.add_argument('--test_only', action='store_true',
                        help='set this option to test the model')
    parser.add_argument('--gan_k', type=int, default=1,
                        help='k value for adversarial loss')

    # Optimization specifications
    parser.add_argument('--lr', type=float, default=1e-4,
                        help='learning rate')
    parser.add_argument('--lr_decay', type=int, default=200,
                        help='learning rate decay per N epochs')
    parser.add_argument('--decay_type', type=str, default='step',
                        help='learning rate decay type')
    parser.add_argument('--gamma', type=float, default=0.5,
                        help='learning rate decay factor for step decay')
    parser.add_argument('--optimizer', default='ADAM',
                        choices=('SGD', 'ADAM', 'RMSprop'),
                        help='optimizer to use (SGD | ADAM | RMSprop)')
    parser.add_argument('--momentum', type=float, default=0.9,
                        help='SGD momentum')
    parser.add_argument('--beta1', type=float, default=0.9,
                        help='ADAM beta1')
    parser.add_argument('--beta2', type=float, default=0.999,
                        help='ADAM beta2')
    parser.add_argument('--epsilon', type=float, default=1e-8,
                        help='ADAM epsilon for numerical stability')
    parser.add_argument('--weight_decay', type=float, default=0,
                        help='weight decay')

    # Loss specifications
    parser.add_argument('--loss', type=str, default='1*L1',
                        help='loss function configuration')
    parser.add_argument('--skip_threshold', type=float, default='1e6',
                        help='skipping batch that has large error')

    # Log specifications
    parser.add_argument('--save', type=str, default='RCAN',
                        help='file name to save')
    parser.add_argument('--load', type=str, default='.',
                        help='file name to load')
    parser.add_argument('--resume', type=int, default=0,
                        help='resume from specific checkpoint')
    parser.add_argument('--print_model', action='store_true',
                        help='print model')
    parser.add_argument('--save_models', action='store_true',
                        help='save all intermediate models')
    parser.add_argument('--print_every', type=int, default=100,
                        help='how many batches to wait before logging training status')
    parser.add_argument('--save_results', action='store_true',
                        help='save output results')

    # New options
    parser.add_argument('--n_resgroups', type=int, default=10,
                        help='number of residual groups')
    parser.add_argument('--reduction', type=int, default=16,
                        help='number of feature maps reduction')
    parser.add_argument('--testpath', type=str, default='../test/DIV2K_val_LR_our',
                        help='dataset directory for testing')
    parser.add_argument('--testset', type=str, default='Set5',
                        help='dataset name for testing')
    parser.add_argument('--degradation', type=str, default='BI',
                        help='degradation model: BI, BD')
    # args = []
    # args = parser.parse_known_args()[0]
    # import platform 
    # sys = platform.system()
    # if sys == "Windows":
    #     args = parser.parse_args(args=[])
    # else:
    #     args = parser.parse_args()

    # args = parser.parse_args()


    #     template.set_template(args)

    args = parser.parse_args(args=[])

    args.scale = list(map(lambda x: int(x), args.scale.split('+')))

    if args.epochs == 0:
        args.epochs = 1e8

    for arg in vars(args):
        if vars(args)[arg] == 'True':
            vars(args)[arg] = True
        elif vars(args)[arg] == 'False':
            vars(args)[arg] = False
    return args




args=set_args()

args.file_ACCESS_dir="../data/"
args.file_BARRA_dir="../data/barra_aus/"
args.file_DEM_dir="../DEM/"

init_date=date(1970, 1, 1)
start_date=date(1990, 1, 2)
end_date=date(1990,12,10)
args.channels=0
args.dem=0
args.psl=0
args.zg=1
args.tasmax=1
args.tasmin=0



if args.pr:
    args.channels+=1
if args.zg:
    args.channels+=1
if args.psl:
    args.channels+=1
if args.tasmax:
    args.channels+=1
if args.tasmin:
    args.channels+=1
if args.dem:
    args.channels+=1
access_rgb_mean= 2.9067910245780248e-05*86400

leading_time=217
args.leading_time_we_use=7
args.ensemble=2

# %%
import os
import data_processing_tool as dpt
from datetime import timedelta, date, datetime
# from args_parameter import args
from PrepareData import ACCESS_BARRA_v2_0
import torch
import torch,os,torchvision
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader,random_split
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim

# from PIL import Image
import time
from sklearn.model_selection import StratifiedShuffleSplit
import model
from model import my_model
import utility
from tqdm import tqdm
import math
import xarray as xr
from skimage.measure import compare_ssim
from skimage.measure import compare_psnr,compare_mse
import platform
from torch.autograd import Variable


def write_log(log):
    print(log)
    my_log_file=open("./model/save/"+args.train_name + '/train.txt', 'a')
#     log="Train for batch %d,data loading time cost %f s"%(batch,start-time.time())
    my_log_file.write(log + '\n')
    my_log_file.close()
    return


def main():
    
#     pre_train_path="./model/save/temp01/"+0+".pth"

    
    
    init_date=date(1970, 1, 1)
    start_date=date(1990, 1, 2)
    end_date=date(1990,12,25)
#     end_date=date(2012,12,25) #if 929 is true we should substract 1 day    
    sys = platform.system()
    args.file_ACCESS_dir="../data/"
    args.file_BARRA_dir="../data/barra_aus/"
    if sys == "Windows":
        init_date=date(1970, 1, 1)
        start_date=date(1990, 1, 2)
        end_date=date(1990,12,15) #if 929 is true we should substract 1 day   
        args.cpu=True
#         args.file_ACCESS_dir="E:/climate/access-s1/"
#         args.file_BARRA_dir="C:/Users/JIA059/barra/"
        args.file_DEM_dir="../DEM/"
    else:
        args.file_ACCESS_dir_pr="/g/data/ub7/access-s1/hc/raw_model/atmos/pr/daily/"
        args.file_ACCESS_dir="/g/data/ub7/access-s1/hc/raw_model/atmos/"
        # training_name="temp01"
        args.file_BARRA_dir="/g/data/ma05/BARRA_R/v1/forecast/spec/accum_prcp/"

    args.channels=0
    if args.pr:
        args.channels+=1
    if args.zg:
        args.channels+=1
    if args.psl:
        args.channels+=1
    if args.tasmax:
        args.channels+=1
    if args.tasmin:
        args.channels+=1
    if args.dem:
        args.channels+=1
    access_rgb_mean= 2.9067910245780248e-05*86400
    pre_train_path="./model/save/"+args.train_name+"/last_"+str(args.channels)+".pth"
    leading_time=217
    args.leading_time_we_use=1
    args.ensemble=1


    print(access_rgb_mean)

    print("training statistics:")
    print("  ------------------------------")
    print("  trainning name  |  %s"%args.train_name)
    print("  ------------------------------")
    print("  num of channels | %5d"%args.channels)
    print("  ------------------------------")
    print("  num of threads  | %5d"%args.n_threads)
    print("  ------------------------------")
    print("  batch_size     | %5d"%args.batch_size)
    print("  ------------------------------")
    print("  using cpu only？ | %5d"%args.cpu)

    ############################################################################################

    train_transforms = transforms.Compose([
    #     transforms.Resize(IMG_SIZE),
    #     transforms.RandomResizedCrop(IMG_SIZE),
    #     transforms.RandomHorizontalFlip(),
    #     transforms.RandomRotation(30),
        transforms.ToTensor()
    #     transforms.Normalize(IMG_MEAN, IMG_STD)
    ])

    data_set=ACCESS_BARRA_v2_0(start_date,end_date,transform=train_transforms,args=args)
    train_data,val_data=random_split(data_set,[int(len(data_set)*0.8),len(data_set)-int(len(data_set)*0.8)])


    print("Dataset statistics:")
    print("  ------------------------------")
    print("  total | %5d"%len(data_set))
    print("  ------------------------------")
    print("  train | %5d"%len(train_data))
    print("  ------------------------------")
    print("  val   | %5d"%len(val_data))

    ###################################################################################set a the dataLoader
    train_dataloders =DataLoader(train_data,
                                            batch_size=args.batch_size,
                                            shuffle=True,
                                num_workers=args.n_threads)
    val_dataloders =DataLoader(val_data,
                                            batch_size=args.batch_size,
                                            shuffle=True,
                              num_workers=args.n_threads)
    ##
    def prepare( l, volatile=False):
        def _prepare(tensor):
            if args.precision == 'half': tensor = tensor.half()
            if args.precision == 'single': tensor = tensor.float()
            return tensor.to(device)

        return [_prepare(_l) for _l in l]
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    checkpoint = utility.checkpoint(args)
    net = model.Model(args, checkpoint)
#     net.load("./model/RCAN_BIX4.pt", pre_train="./model/RCAN_BIX4.pt", resume=args.resume, cpu=True)
#     my_net=my_model.Modify_RCAN(net,args,checkpoint)

#     net.load("./model/RCAN_BIX4.pt", pre_train="./model/RCAN_BIX4.pt", resume=args.resume, cpu=args.cpu)
    
    args.lr=0.001
    criterion = nn.L1Loss()
    optimizer_my = optim.SGD(net.parameters(), lr=args.lr, momentum=0.9)
    # scheduler = optim.lr_scheduler.StepLR(optimizer_my, step_size=7, gamma=0.1)
    scheduler = optim.lr_scheduler.ExponentialLR(optimizer_my, gamma=0.9)
    # torch.optim.lr_scheduler.MultiStepLR(optimizer_my, milestones=[20,80], gamma=0.1)
    
#     if args.resume==1:
#         print("continue last train")
#         model_checkpoint = torch.load(pre_train_path,map_location=device)
#     else:
#         print("restart train")
#         model_checkpoint = torch.load("./model/save/"+args.train_name+"/first_"+str(args.channels)+".pth",map_location=device)

#     my_net.load_state_dict(model_checkpoint['model'])
#     optimizer_my.load_state_dict(model_checkpoint['optimizer'])
#     epoch = model_checkpoint['epoch']
    
    if torch.cuda.device_count() > 1:
        write_log("Let's use"+str(torch.cuda.device_count())+"GPUs!")
        # dim = 0 [30, xxx] -> [10, ...], [10, ...], [10, ...] on 3 GPUs
        my_net = nn.DataParallel(my_net)
    else:
        write_log("Let's use"+str(torch.cuda.device_count())+"GPUs!")

#     my_net = torch.nn.DataParallel(my_net)
    net.to(device)
    
    ##########################################################################training

    write_log("start")
    max_error=np.inf
    for e in range(args.epochs):
        #train
        net.train()
        loss=0
        start=time.time()
        for batch, (lr,hr,_,_) in enumerate(train_dataloders):
            write_log("Train for batch %d,data loading time cost %f s"%(batch,start-time.time()))
            start=time.time()
            lr,hr= prepare([lr,hr])

            optimizer_my.zero_grad()
            with torch.set_grad_enabled(True):
                sr = net(lr,0)
                running_loss =criterion(sr, hr,tasmax=tasmax)

                running_loss.backward()
                optimizer_my.step()
            loss+=running_loss #.copy()?
            if batch%10==0:
                state = {'model': my_net.state_dict(), 'optimizer': optimizer_my.state_dict(), 'epoch': e}
                torch.save(state, "./model/save/temp01/last.pth")
            write_log("Train done,train time cost %f s,loss: %f"%(start-time.time(),running_loss.item()  ))
            start=time.time()

        #validation
        net.eval()
        start=time.time()
        with torch.no_grad():
            eval_psnr=0
            eval_ssim=0
#             tqdm_val = tqdm(val_dataloders, ncols=80)
            for idx_img, (lr,hr,_,_) in enumerate(val_dataloders):
                lr,hr = prepare([lr, hr])
                sr = net(lr,0)
                val_loss=criterion(sr, hr)
                for ssr,hhr in zip(sr,hr):
                    eval_psnr+=compare_psnr(ssr[0].cpu().numpy(),hhr[0].cpu().numpy(),data_range=(hhr[0].cpu().max()-hhr[0].cpu().min()).item() )
                    eval_ssim+=compare_ssim(ssr[0].cpu().numpy(),hhr[0].cpu().numpy(),data_range=(hhr[0].cpu().max()-hhr[0].cpu().min()).item() )

        write_log("epoche: %d,time cost %f s, lr: %f, train_loss: %f,validation loss:%f "%(
                  e,
                  time.time()-start,
                  optimizer_my.state_dict()['param_groups'][0]['lr'],
                  loss.item()/len(train_data),
                  val_loss
             ))
#         print("epoche: %d,time cost %f s, lr: %f, train_loss: %f,validation loss:%f "%(
#                   e,
#                   time.time()-start,
#                   optimizer_my.state_dict()['param_groups'][0]['lr'],
#                   loss.item()/len(train_data),
#                   val_loss
#              ))
        if running_loss<max_error:
            max_error=running_loss
    #         torch.save(net,train_loss"_"+str(e)+".pkl")
            if not os.path.exists("./model/save/"+args.train_name+"/"):
                os.mkdir("./model/save/"+args.train_name+"/")
            write_log("saving")
            state = {'model': my_net.state_dict(), 'optimizer': optimizer_my.state_dict(), 'epoch': e}
            torch.save(state, "./model/save/temp01/"+str(e)+".pth")


            
# if __name__=='__main__':
#     main()

# %%
# main()


import os
import data_processing_tool as dpt
from datetime import timedelta, date, datetime
# from args_parameter import args
from PrepareData import ACCESS_BARRA_v2_0
import torch
import torch,os,torchvision
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader,random_split
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim

# from PIL import Image
import time
from sklearn.model_selection import StratifiedShuffleSplit
import model
from model import my_model
import utility
from tqdm import tqdm
import math
import xarray as xr
from skimage.measure import compare_ssim
from skimage.measure import compare_psnr,compare_mse
import platform
from torch.autograd import Variable




def write_log(log):
    print(log)
    my_log_file=open("./model/save/"+args.train_name + '/train.txt', 'a')
#     log="Train for batch %d,data loading time cost %f s"%(batch,start-time.time())
    my_log_file.write(log + '\n')
    my_log_file.close()
    return

# %%
init_date=date(1970, 1, 1)
start_date=date(1990, 1, 2)
end_date=date(1990,12,25)
#     end_date=date(2012,12,25) #if 929 is true we should substract 1 day    
sys = platform.system()
args.file_ACCESS_dir="../data/"
args.file_BARRA_dir="../data/barra_aus/"
if sys == "Windows":
    init_date=date(1970, 1, 1)
    start_date=date(1990, 1, 2)
    end_date=date(1990,12,15) #if 929 is true we should substract 1 day   
    args.cpu=True
#         args.file_ACCESS_dir="E:/climate/access-s1/"
#         args.file_BARRA_dir="C:/Users/JIA059/barra/"
    args.file_DEM_dir="../DEM/"
else:
    args.file_ACCESS_dir_pr="/g/data/ub7/access-s1/hc/raw_model/atmos/pr/daily/"
    args.file_ACCESS_dir="/g/data/ub7/access-s1/hc/raw_model/atmos/"
    # training_name="temp01"
    args.file_BARRA_dir="/g/data/ma05/BARRA_R/v1/forecast/spec/accum_prcp/"

args.channels=0
if args.pr:
    args.channels+=1
if args.zg:
    args.channels+=1
if args.psl:
    args.channels+=1
if args.tasmax:
    args.channels+=1
if args.tasmin:
    args.channels+=1
if args.dem:
    args.channels+=1
access_rgb_mean= 2.9067910245780248e-05*86400
pre_train_path="./model/save/"+args.train_name+"/last_"+str(args.channels)+".pth"
leading_time=217
args.leading_time_we_use=1
args.ensemble=1


print(access_rgb_mean)

print("training statistics:")
print("  ------------------------------")
print("  trainning name  |  %s"%args.train_name)
print("  ------------------------------")
print("  num of channels | %5d"%args.channels)
print("  ------------------------------")
print("  num of threads  | %5d"%args.n_threads)
print("  ------------------------------")
print("  batch_size     | %5d"%args.batch_size)
print("  ------------------------------")
print("  using cpu only？ | %5d"%args.cpu)

############################################################################################

train_transforms = transforms.Compose([
#     transforms.Resize(IMG_SIZE),
#     transforms.RandomResizedCrop(IMG_SIZE),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomRotation(30),
    transforms.ToTensor()
#     transforms.Normalize(IMG_MEAN, IMG_STD)
])

data_set=ACCESS_BARRA_v2_0(start_date,end_date,transform=train_transforms,args=args)
train_data,val_data=random_split(data_set,[int(len(data_set)*0.8),len(data_set)-int(len(data_set)*0.8)])


print("Dataset statistics:")
print("  ------------------------------")
print("  total | %5d"%len(data_set))
print("  ------------------------------")
print("  train | %5d"%len(train_data))
print("  ------------------------------")
print("  val   | %5d"%len(val_data))

###################################################################################set a the dataLoader
args.batch_size=2
train_dataloders =DataLoader(train_data,
                                        batch_size=args.batch_size,
                                        shuffle=True,
                            num_workers=args.n_threads)
val_dataloders =DataLoader(val_data,
                                        batch_size=args.batch_size,
                                        shuffle=True,
                          num_workers=args.n_threads)
##
def prepare( l, volatile=False):
    def _prepare(tensor):
        if args.precision == 'half': tensor = tensor.half()
        if args.precision == 'single': tensor = tensor.float()
        return tensor.to(device)

    return [_prepare(_l) for _l in l]
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

checkpoint = utility.checkpoint(args)


net = model.Model(args, checkpoint)
#     net.load("./model/RCAN_BIX4.pt", pre_train="./model/RCAN_BIX4.pt", resume=args.resume, cpu=True)
my_net=my_model.Modify_RCAN(net,args,checkpoint)

#     net.load("./model/RCAN_BIX4.pt", pre_train="./model/RCAN_BIX4.pt", resume=args.resume, cpu=args.cpu)

args.lr=0.001
criterion = nn.L1Loss()
optimizer_my = optim.SGD(net.parameters(), lr=args.lr, momentum=0.9)
# scheduler = optim.lr_scheduler.StepLR(optimizer_my, step_size=7, gamma=0.1)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer_my, gamma=0.9)
# torch.optim.lr_scheduler.MultiStepLR(optimizer_my, milestones=[20,80], gamma=0.1)

#     if args.resume==1:
#         print("continue last train")
#         model_checkpoint = torch.load(pre_train_path,map_location=device)
#     else:
#         print("restart train")
#         model_checkpoint = torch.load("./model/save/"+args.train_name+"/first_"+str(args.channels)+".pth",map_location=device)

#     my_net.load_state_dict(model_checkpoint['model'])
#     optimizer_my.load_state_dict(model_checkpoint['optimizer'])
#     epoch = model_checkpoint['epoch']

# if torch.cuda.device_count() > 1:
#     write_log("Let's use"+str(torch.cuda.device_count())+"GPUs!")
    # dim = 0 [30, xxx] -> [10, ...], [10, ...], [10, ...] on 3 GPUs
#     my_net = nn.DataParallel(my_net)
# else:
#     write_log("Let's use"+str(torch.cuda.device_count())+"GPUs!")

#     my_net = torch.nn.DataParallel(my_net)
net.to(device)
# Out:
# 2.5114674452354135
# training statistics:
#   ------------------------------
#   trainning name  |  temp01
#   ------------------------------
#   num of channels |     3
#   ------------------------------
#   num of threads  |     0
#   ------------------------------
#   batch_size     |     2
#   ------------------------------
#   using cpu only？ |     1
# => BARRA_R & ACCESS_S1 loading
# => from 1990/01/02 to 1990/12/15
# ../data/barra_aus/
# no file or no permission!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Dataset statistics:
#   ------------------------------
#   total |    45
#   ------------------------------
#   train |    36
#   ------------------------------
#   val   |     9
# Making model...
# accesss-s1 mean (0.4690)
# Loading model from ./model/RCAN_BIX4.pt
# Model(
#   (model): RCAN(
#     (sub_mean_my): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (add_mean_my): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (head): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (body): Sequential(
#       (0): ResidualGroup(
#         (body): Sequential(
#           (0): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (1): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (2): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (3): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (4): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (5): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (6): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (7): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (8): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (9): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (10): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (11): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (12): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (13): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (14): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (15): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (1): ResidualGroup(
#         (body): Sequential(
#           (0): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (1): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (2): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (3): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (4): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (5): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (6): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (7): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (8): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (9): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (10): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (11): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (12): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (13): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (14): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (15): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (2): ResidualGroup(
#         (body): Sequential(
#           (0): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (1): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (2): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (3): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (4): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (5): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (6): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (7): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (8): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (9): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (10): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (11): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (12): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (13): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (14): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (15): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (3): ResidualGroup(
#         (body): Sequential(
#           (0): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (1): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (2): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (3): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (4): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (5): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (6): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (7): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (8): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (9): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (10): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (11): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (12): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (13): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (14): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (15): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (4): ResidualGroup(
#         (body): Sequential(
#           (0): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (1): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (2): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (3): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (4): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (5): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
# ...
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (10): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (11): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (12): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (13): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (14): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (15): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (9): ResidualGroup(
#         (body): Sequential(
#           (0): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (1): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (2): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (3): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (4): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (5): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (6): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (7): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (8): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (9): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (10): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (11): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (12): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (13): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (14): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (15): RCAB(
#             (body): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): CALayer(
#                 (avg_pool): AdaptiveAvgPool2d(output_size=1)
#                 (conv_du): Sequential(
#                   (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                   (1): ReLU(inplace=True)
#                   (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (3): Sigmoid()
#                 )
#               )
#             )
#           )
#           (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (tail): Sequential(
#       (0): Upsampler(
#         (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PixelShuffle(upscale_factor=2)
#         (2): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PixelShuffle(upscale_factor=2)
#       )
#       (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
for batch, (lr,hr,_,_) in enumerate(train_dataloders):
    print(lr.shape)
    break
# Out:
# torch.Size([2, 3, 79, 94])

# %%
import torch.optim as optim

optimizer_my = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)
# scheduler = optim.lr_scheduler.StepLR(optimizer_my, step_size=50, gamma=0.1)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer_my, gamma=0.99)
for i in range(300):
    scheduler.step()
    print(scheduler.state_dict())
# Out:
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 1, '_step_count': 2, '_get_lr_called_within_step': False, '_last_lr': [9.900000000000001e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 2, '_step_count': 3, '_get_lr_called_within_step': False, '_last_lr': [9.801e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 3, '_step_count': 4, '_get_lr_called_within_step': False, '_last_lr': [9.70299e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 4, '_step_count': 5, '_get_lr_called_within_step': False, '_last_lr': [9.605960100000001e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 5, '_step_count': 6, '_get_lr_called_within_step': False, '_last_lr': [9.509900499000001e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 6, '_step_count': 7, '_get_lr_called_within_step': False, '_last_lr': [9.414801494010001e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 7, '_step_count': 8, '_get_lr_called_within_step': False, '_last_lr': [9.320653479069902e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 8, '_step_count': 9, '_get_lr_called_within_step': False, '_last_lr': [9.227446944279203e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 9, '_step_count': 10, '_get_lr_called_within_step': False, '_last_lr': [9.13517247483641e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 10, '_step_count': 11, '_get_lr_called_within_step': False, '_last_lr': [9.043820750088047e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 11, '_step_count': 12, '_get_lr_called_within_step': False, '_last_lr': [8.953382542587167e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 12, '_step_count': 13, '_get_lr_called_within_step': False, '_last_lr': [8.863848717161295e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 13, '_step_count': 14, '_get_lr_called_within_step': False, '_last_lr': [8.775210229989682e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 14, '_step_count': 15, '_get_lr_called_within_step': False, '_last_lr': [8.687458127689785e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 15, '_step_count': 16, '_get_lr_called_within_step': False, '_last_lr': [8.600583546412887e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 16, '_step_count': 17, '_get_lr_called_within_step': False, '_last_lr': [8.514577710948758e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 17, '_step_count': 18, '_get_lr_called_within_step': False, '_last_lr': [8.429431933839271e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 18, '_step_count': 19, '_get_lr_called_within_step': False, '_last_lr': [8.345137614500879e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 19, '_step_count': 20, '_get_lr_called_within_step': False, '_last_lr': [8.26168623835587e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 20, '_step_count': 21, '_get_lr_called_within_step': False, '_last_lr': [8.17906937597231e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 21, '_step_count': 22, '_get_lr_called_within_step': False, '_last_lr': [8.097278682212587e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 22, '_step_count': 23, '_get_lr_called_within_step': False, '_last_lr': [8.016305895390461e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 23, '_step_count': 24, '_get_lr_called_within_step': False, '_last_lr': [7.936142836436556e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 24, '_step_count': 25, '_get_lr_called_within_step': False, '_last_lr': [7.856781408072191e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 25, '_step_count': 26, '_get_lr_called_within_step': False, '_last_lr': [7.778213593991469e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 26, '_step_count': 27, '_get_lr_called_within_step': False, '_last_lr': [7.700431458051554e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 27, '_step_count': 28, '_get_lr_called_within_step': False, '_last_lr': [7.623427143471038e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 28, '_step_count': 29, '_get_lr_called_within_step': False, '_last_lr': [7.547192872036328e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 29, '_step_count': 30, '_get_lr_called_within_step': False, '_last_lr': [7.471720943315964e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 30, '_step_count': 31, '_get_lr_called_within_step': False, '_last_lr': [7.397003733882805e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 31, '_step_count': 32, '_get_lr_called_within_step': False, '_last_lr': [7.323033696543977e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 32, '_step_count': 33, '_get_lr_called_within_step': False, '_last_lr': [7.249803359578537e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 33, '_step_count': 34, '_get_lr_called_within_step': False, '_last_lr': [7.177305325982752e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 34, '_step_count': 35, '_get_lr_called_within_step': False, '_last_lr': [7.105532272722923e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 35, '_step_count': 36, '_get_lr_called_within_step': False, '_last_lr': [7.034476949995695e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 36, '_step_count': 37, '_get_lr_called_within_step': False, '_last_lr': [6.964132180495738e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 37, '_step_count': 38, '_get_lr_called_within_step': False, '_last_lr': [6.89449085869078e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 38, '_step_count': 39, '_get_lr_called_within_step': False, '_last_lr': [6.825545950103872e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 39, '_step_count': 40, '_get_lr_called_within_step': False, '_last_lr': [6.757290490602833e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 40, '_step_count': 41, '_get_lr_called_within_step': False, '_last_lr': [6.689717585696805e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 41, '_step_count': 42, '_get_lr_called_within_step': False, '_last_lr': [6.622820409839837e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 42, '_step_count': 43, '_get_lr_called_within_step': False, '_last_lr': [6.556592205741439e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 43, '_step_count': 44, '_get_lr_called_within_step': False, '_last_lr': [6.491026283684025e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 44, '_step_count': 45, '_get_lr_called_within_step': False, '_last_lr': [6.426116020847184e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 45, '_step_count': 46, '_get_lr_called_within_step': False, '_last_lr': [6.361854860638712e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 46, '_step_count': 47, '_get_lr_called_within_step': False, '_last_lr': [6.298236312032325e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 47, '_step_count': 48, '_get_lr_called_within_step': False, '_last_lr': [6.235253948912002e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 48, '_step_count': 49, '_get_lr_called_within_step': False, '_last_lr': [6.172901409422881e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 49, '_step_count': 50, '_get_lr_called_within_step': False, '_last_lr': [6.111172395328652e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 50, '_step_count': 51, '_get_lr_called_within_step': False, '_last_lr': [6.050060671375366e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 51, '_step_count': 52, '_get_lr_called_within_step': False, '_last_lr': [5.9895600646616125e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 52, '_step_count': 53, '_get_lr_called_within_step': False, '_last_lr': [5.9296644640149966e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 53, '_step_count': 54, '_get_lr_called_within_step': False, '_last_lr': [5.8703678193748465e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 54, '_step_count': 55, '_get_lr_called_within_step': False, '_last_lr': [5.811664141181098e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 55, '_step_count': 56, '_get_lr_called_within_step': False, '_last_lr': [5.753547499769287e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 56, '_step_count': 57, '_get_lr_called_within_step': False, '_last_lr': [5.696012024771594e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 57, '_step_count': 58, '_get_lr_called_within_step': False, '_last_lr': [5.639051904523878e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 58, '_step_count': 59, '_get_lr_called_within_step': False, '_last_lr': [5.5826613854786396e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 59, '_step_count': 60, '_get_lr_called_within_step': False, '_last_lr': [5.5268347716238534e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 60, '_step_count': 61, '_get_lr_called_within_step': False, '_last_lr': [5.471566423907615e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 61, '_step_count': 62, '_get_lr_called_within_step': False, '_last_lr': [5.416850759668539e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 62, '_step_count': 63, '_get_lr_called_within_step': False, '_last_lr': [5.362682252071853e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 63, '_step_count': 64, '_get_lr_called_within_step': False, '_last_lr': [5.309055429551135e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 64, '_step_count': 65, '_get_lr_called_within_step': False, '_last_lr': [5.2559648752556236e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 65, '_step_count': 66, '_get_lr_called_within_step': False, '_last_lr': [5.203405226503067e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 66, '_step_count': 67, '_get_lr_called_within_step': False, '_last_lr': [5.1513711742380364e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 67, '_step_count': 68, '_get_lr_called_within_step': False, '_last_lr': [5.099857462495656e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 68, '_step_count': 69, '_get_lr_called_within_step': False, '_last_lr': [5.0488588878706996e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 69, '_step_count': 70, '_get_lr_called_within_step': False, '_last_lr': [4.9983702989919924e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 70, '_step_count': 71, '_get_lr_called_within_step': False, '_last_lr': [4.9483865960020725e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 71, '_step_count': 72, '_get_lr_called_within_step': False, '_last_lr': [4.898902730042052e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 72, '_step_count': 73, '_get_lr_called_within_step': False, '_last_lr': [4.8499137027416314e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 73, '_step_count': 74, '_get_lr_called_within_step': False, '_last_lr': [4.801414565714215e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 74, '_step_count': 75, '_get_lr_called_within_step': False, '_last_lr': [4.753400420057073e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 75, '_step_count': 76, '_get_lr_called_within_step': False, '_last_lr': [4.705866415856502e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 76, '_step_count': 77, '_get_lr_called_within_step': False, '_last_lr': [4.658807751697937e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 77, '_step_count': 78, '_get_lr_called_within_step': False, '_last_lr': [4.6122196741809574e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 78, '_step_count': 79, '_get_lr_called_within_step': False, '_last_lr': [4.566097477439148e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 79, '_step_count': 80, '_get_lr_called_within_step': False, '_last_lr': [4.520436502664756e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 80, '_step_count': 81, '_get_lr_called_within_step': False, '_last_lr': [4.475232137638109e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 81, '_step_count': 82, '_get_lr_called_within_step': False, '_last_lr': [4.430479816261728e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 82, '_step_count': 83, '_get_lr_called_within_step': False, '_last_lr': [4.3861750180991104e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 83, '_step_count': 84, '_get_lr_called_within_step': False, '_last_lr': [4.3423132679181194e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 84, '_step_count': 85, '_get_lr_called_within_step': False, '_last_lr': [4.298890135238938e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 85, '_step_count': 86, '_get_lr_called_within_step': False, '_last_lr': [4.255901233886549e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 86, '_step_count': 87, '_get_lr_called_within_step': False, '_last_lr': [4.213342221547683e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 87, '_step_count': 88, '_get_lr_called_within_step': False, '_last_lr': [4.1712087993322064e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 88, '_step_count': 89, '_get_lr_called_within_step': False, '_last_lr': [4.1294967113388845e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 89, '_step_count': 90, '_get_lr_called_within_step': False, '_last_lr': [4.0882017442254956e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 90, '_step_count': 91, '_get_lr_called_within_step': False, '_last_lr': [4.04731972678324e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 91, '_step_count': 92, '_get_lr_called_within_step': False, '_last_lr': [4.006846529515408e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 92, '_step_count': 93, '_get_lr_called_within_step': False, '_last_lr': [3.966778064220254e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 93, '_step_count': 94, '_get_lr_called_within_step': False, '_last_lr': [3.927110283578051e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 94, '_step_count': 95, '_get_lr_called_within_step': False, '_last_lr': [3.8878391807422704e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 95, '_step_count': 96, '_get_lr_called_within_step': False, '_last_lr': [3.8489607889348474e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 96, '_step_count': 97, '_get_lr_called_within_step': False, '_last_lr': [3.8104711810454986e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 97, '_step_count': 98, '_get_lr_called_within_step': False, '_last_lr': [3.7723664692350434e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 98, '_step_count': 99, '_get_lr_called_within_step': False, '_last_lr': [3.734642804542693e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 99, '_step_count': 100, '_get_lr_called_within_step': False, '_last_lr': [3.697296376497266e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 100, '_step_count': 101, '_get_lr_called_within_step': False, '_last_lr': [3.660323412732293e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 101, '_step_count': 102, '_get_lr_called_within_step': False, '_last_lr': [3.62372017860497e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 102, '_step_count': 103, '_get_lr_called_within_step': False, '_last_lr': [3.5874829768189206e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 103, '_step_count': 104, '_get_lr_called_within_step': False, '_last_lr': [3.551608147050731e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 104, '_step_count': 105, '_get_lr_called_within_step': False, '_last_lr': [3.516092065580224e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 105, '_step_count': 106, '_get_lr_called_within_step': False, '_last_lr': [3.480931144924422e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 106, '_step_count': 107, '_get_lr_called_within_step': False, '_last_lr': [3.4461218334751775e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 107, '_step_count': 108, '_get_lr_called_within_step': False, '_last_lr': [3.4116606151404254e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 108, '_step_count': 109, '_get_lr_called_within_step': False, '_last_lr': [3.377544008989021e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 109, '_step_count': 110, '_get_lr_called_within_step': False, '_last_lr': [3.343768568899131e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 110, '_step_count': 111, '_get_lr_called_within_step': False, '_last_lr': [3.31033088321014e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 111, '_step_count': 112, '_get_lr_called_within_step': False, '_last_lr': [3.277227574378038e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 112, '_step_count': 113, '_get_lr_called_within_step': False, '_last_lr': [3.244455298634257e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 113, '_step_count': 114, '_get_lr_called_within_step': False, '_last_lr': [3.2120107456479144e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 114, '_step_count': 115, '_get_lr_called_within_step': False, '_last_lr': [3.179890638191435e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 115, '_step_count': 116, '_get_lr_called_within_step': False, '_last_lr': [3.1480917318095206e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 116, '_step_count': 117, '_get_lr_called_within_step': False, '_last_lr': [3.1166108144914254e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 117, '_step_count': 118, '_get_lr_called_within_step': False, '_last_lr': [3.085444706346511e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 118, '_step_count': 119, '_get_lr_called_within_step': False, '_last_lr': [3.054590259283046e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 119, '_step_count': 120, '_get_lr_called_within_step': False, '_last_lr': [3.0240443566902154e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 120, '_step_count': 121, '_get_lr_called_within_step': False, '_last_lr': [2.9938039131233132e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 121, '_step_count': 122, '_get_lr_called_within_step': False, '_last_lr': [2.96386587399208e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 122, '_step_count': 123, '_get_lr_called_within_step': False, '_last_lr': [2.9342272152521593e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 123, '_step_count': 124, '_get_lr_called_within_step': False, '_last_lr': [2.9048849430996377e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 124, '_step_count': 125, '_get_lr_called_within_step': False, '_last_lr': [2.8758360936686414e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 125, '_step_count': 126, '_get_lr_called_within_step': False, '_last_lr': [2.847077732731955e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 126, '_step_count': 127, '_get_lr_called_within_step': False, '_last_lr': [2.8186069554046354e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 127, '_step_count': 128, '_get_lr_called_within_step': False, '_last_lr': [2.790420885850589e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 128, '_step_count': 129, '_get_lr_called_within_step': False, '_last_lr': [2.762516676992083e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 129, '_step_count': 130, '_get_lr_called_within_step': False, '_last_lr': [2.7348915102221623e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 130, '_step_count': 131, '_get_lr_called_within_step': False, '_last_lr': [2.7075425951199406e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 131, '_step_count': 132, '_get_lr_called_within_step': False, '_last_lr': [2.680467169168741e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 132, '_step_count': 133, '_get_lr_called_within_step': False, '_last_lr': [2.653662497477054e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 133, '_step_count': 134, '_get_lr_called_within_step': False, '_last_lr': [2.6271258725022834e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 134, '_step_count': 135, '_get_lr_called_within_step': False, '_last_lr': [2.6008546137772605e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 135, '_step_count': 136, '_get_lr_called_within_step': False, '_last_lr': [2.574846067639488e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 136, '_step_count': 137, '_get_lr_called_within_step': False, '_last_lr': [2.549097606963093e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 137, '_step_count': 138, '_get_lr_called_within_step': False, '_last_lr': [2.523606630893462e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 138, '_step_count': 139, '_get_lr_called_within_step': False, '_last_lr': [2.4983705645845275e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 139, '_step_count': 140, '_get_lr_called_within_step': False, '_last_lr': [2.4733868589386822e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 140, '_step_count': 141, '_get_lr_called_within_step': False, '_last_lr': [2.4486529903492954e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 141, '_step_count': 142, '_get_lr_called_within_step': False, '_last_lr': [2.4241664604458026e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 142, '_step_count': 143, '_get_lr_called_within_step': False, '_last_lr': [2.3999247958413444e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 143, '_step_count': 144, '_get_lr_called_within_step': False, '_last_lr': [2.375925547882931e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 144, '_step_count': 145, '_get_lr_called_within_step': False, '_last_lr': [2.3521662924041017e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 145, '_step_count': 146, '_get_lr_called_within_step': False, '_last_lr': [2.3286446294800605e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 146, '_step_count': 147, '_get_lr_called_within_step': False, '_last_lr': [2.30535818318526e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 147, '_step_count': 148, '_get_lr_called_within_step': False, '_last_lr': [2.2823046013534073e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 148, '_step_count': 149, '_get_lr_called_within_step': False, '_last_lr': [2.259481555339873e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 149, '_step_count': 150, '_get_lr_called_within_step': False, '_last_lr': [2.2368867397864743e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 150, '_step_count': 151, '_get_lr_called_within_step': False, '_last_lr': [2.2145178723886096e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 151, '_step_count': 152, '_get_lr_called_within_step': False, '_last_lr': [2.1923726936647233e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 152, '_step_count': 153, '_get_lr_called_within_step': False, '_last_lr': [2.170448966728076e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 153, '_step_count': 154, '_get_lr_called_within_step': False, '_last_lr': [2.1487444770607954e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 154, '_step_count': 155, '_get_lr_called_within_step': False, '_last_lr': [2.1272570322901873e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 155, '_step_count': 156, '_get_lr_called_within_step': False, '_last_lr': [2.1059844619672853e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 156, '_step_count': 157, '_get_lr_called_within_step': False, '_last_lr': [2.0849246173476125e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 157, '_step_count': 158, '_get_lr_called_within_step': False, '_last_lr': [2.0640753711741364e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 158, '_step_count': 159, '_get_lr_called_within_step': False, '_last_lr': [2.043434617462395e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 159, '_step_count': 160, '_get_lr_called_within_step': False, '_last_lr': [2.023000271287771e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 160, '_step_count': 161, '_get_lr_called_within_step': False, '_last_lr': [2.0027702685748933e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 161, '_step_count': 162, '_get_lr_called_within_step': False, '_last_lr': [1.9827425658891444e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 162, '_step_count': 163, '_get_lr_called_within_step': False, '_last_lr': [1.9629151402302528e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 163, '_step_count': 164, '_get_lr_called_within_step': False, '_last_lr': [1.94328598882795e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 164, '_step_count': 165, '_get_lr_called_within_step': False, '_last_lr': [1.9238531289396705e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 165, '_step_count': 166, '_get_lr_called_within_step': False, '_last_lr': [1.9046145976502736e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 166, '_step_count': 167, '_get_lr_called_within_step': False, '_last_lr': [1.885568451673771e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 167, '_step_count': 168, '_get_lr_called_within_step': False, '_last_lr': [1.8667127671570333e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 168, '_step_count': 169, '_get_lr_called_within_step': False, '_last_lr': [1.848045639485463e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 169, '_step_count': 170, '_get_lr_called_within_step': False, '_last_lr': [1.8295651830906085e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 170, '_step_count': 171, '_get_lr_called_within_step': False, '_last_lr': [1.8112695312597025e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 171, '_step_count': 172, '_get_lr_called_within_step': False, '_last_lr': [1.7931568359471054e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 172, '_step_count': 173, '_get_lr_called_within_step': False, '_last_lr': [1.7752252675876342e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 173, '_step_count': 174, '_get_lr_called_within_step': False, '_last_lr': [1.7574730149117577e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 174, '_step_count': 175, '_get_lr_called_within_step': False, '_last_lr': [1.73989828476264e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 175, '_step_count': 176, '_get_lr_called_within_step': False, '_last_lr': [1.7224993019150137e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 176, '_step_count': 177, '_get_lr_called_within_step': False, '_last_lr': [1.7052743088958637e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 177, '_step_count': 178, '_get_lr_called_within_step': False, '_last_lr': [1.688221565806905e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 178, '_step_count': 179, '_get_lr_called_within_step': False, '_last_lr': [1.671339350148836e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 179, '_step_count': 180, '_get_lr_called_within_step': False, '_last_lr': [1.6546259566473476e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 180, '_step_count': 181, '_get_lr_called_within_step': False, '_last_lr': [1.638079697080874e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 181, '_step_count': 182, '_get_lr_called_within_step': False, '_last_lr': [1.6216989001100652e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 182, '_step_count': 183, '_get_lr_called_within_step': False, '_last_lr': [1.6054819111089644e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 183, '_step_count': 184, '_get_lr_called_within_step': False, '_last_lr': [1.5894270919978746e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 184, '_step_count': 185, '_get_lr_called_within_step': False, '_last_lr': [1.573532821077896e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 185, '_step_count': 186, '_get_lr_called_within_step': False, '_last_lr': [1.557797492867117e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 186, '_step_count': 187, '_get_lr_called_within_step': False, '_last_lr': [1.5422195179384457e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 187, '_step_count': 188, '_get_lr_called_within_step': False, '_last_lr': [1.5267973227590614e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 188, '_step_count': 189, '_get_lr_called_within_step': False, '_last_lr': [1.5115293495314708e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 189, '_step_count': 190, '_get_lr_called_within_step': False, '_last_lr': [1.496414056036156e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 190, '_step_count': 191, '_get_lr_called_within_step': False, '_last_lr': [1.4814499154757945e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 191, '_step_count': 192, '_get_lr_called_within_step': False, '_last_lr': [1.4666354163210365e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 192, '_step_count': 193, '_get_lr_called_within_step': False, '_last_lr': [1.4519690621578262e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 193, '_step_count': 194, '_get_lr_called_within_step': False, '_last_lr': [1.437449371536248e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 194, '_step_count': 195, '_get_lr_called_within_step': False, '_last_lr': [1.4230748778208856e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 195, '_step_count': 196, '_get_lr_called_within_step': False, '_last_lr': [1.4088441290426767e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 196, '_step_count': 197, '_get_lr_called_within_step': False, '_last_lr': [1.39475568775225e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 197, '_step_count': 198, '_get_lr_called_within_step': False, '_last_lr': [1.3808081308747274e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 198, '_step_count': 199, '_get_lr_called_within_step': False, '_last_lr': [1.36700004956598e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 199, '_step_count': 200, '_get_lr_called_within_step': False, '_last_lr': [1.3533300490703203e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 200, '_step_count': 201, '_get_lr_called_within_step': False, '_last_lr': [1.3397967485796171e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 201, '_step_count': 202, '_get_lr_called_within_step': False, '_last_lr': [1.326398781093821e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 202, '_step_count': 203, '_get_lr_called_within_step': False, '_last_lr': [1.3131347932828827e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 203, '_step_count': 204, '_get_lr_called_within_step': False, '_last_lr': [1.300003445350054e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 204, '_step_count': 205, '_get_lr_called_within_step': False, '_last_lr': [1.2870034108965534e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 205, '_step_count': 206, '_get_lr_called_within_step': False, '_last_lr': [1.2741333767875878e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 206, '_step_count': 207, '_get_lr_called_within_step': False, '_last_lr': [1.261392043019712e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 207, '_step_count': 208, '_get_lr_called_within_step': False, '_last_lr': [1.248778122589515e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 208, '_step_count': 209, '_get_lr_called_within_step': False, '_last_lr': [1.2362903413636198e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 209, '_step_count': 210, '_get_lr_called_within_step': False, '_last_lr': [1.2239274379499836e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 210, '_step_count': 211, '_get_lr_called_within_step': False, '_last_lr': [1.2116881635704838e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 211, '_step_count': 212, '_get_lr_called_within_step': False, '_last_lr': [1.199571281934779e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 212, '_step_count': 213, '_get_lr_called_within_step': False, '_last_lr': [1.1875755691154312e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 213, '_step_count': 214, '_get_lr_called_within_step': False, '_last_lr': [1.1756998134242768e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 214, '_step_count': 215, '_get_lr_called_within_step': False, '_last_lr': [1.163942815290034e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 215, '_step_count': 216, '_get_lr_called_within_step': False, '_last_lr': [1.1523033871371338e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 216, '_step_count': 217, '_get_lr_called_within_step': False, '_last_lr': [1.1407803532657624e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 217, '_step_count': 218, '_get_lr_called_within_step': False, '_last_lr': [1.1293725497331048e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 218, '_step_count': 219, '_get_lr_called_within_step': False, '_last_lr': [1.1180788242357738e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 219, '_step_count': 220, '_get_lr_called_within_step': False, '_last_lr': [1.106898035993416e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 220, '_step_count': 221, '_get_lr_called_within_step': False, '_last_lr': [1.0958290556334818e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 221, '_step_count': 222, '_get_lr_called_within_step': False, '_last_lr': [1.084870765077147e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 222, '_step_count': 223, '_get_lr_called_within_step': False, '_last_lr': [1.0740220574263756e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 223, '_step_count': 224, '_get_lr_called_within_step': False, '_last_lr': [1.0632818368521118e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 224, '_step_count': 225, '_get_lr_called_within_step': False, '_last_lr': [1.0526490184835907e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 225, '_step_count': 226, '_get_lr_called_within_step': False, '_last_lr': [1.0421225282987548e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 226, '_step_count': 227, '_get_lr_called_within_step': False, '_last_lr': [1.0317013030157671e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 227, '_step_count': 228, '_get_lr_called_within_step': False, '_last_lr': [1.0213842899856094e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 228, '_step_count': 229, '_get_lr_called_within_step': False, '_last_lr': [1.0111704470857532e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 229, '_step_count': 230, '_get_lr_called_within_step': False, '_last_lr': [1.0010587426148957e-05]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 230, '_step_count': 231, '_get_lr_called_within_step': False, '_last_lr': [9.910481551887467e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 231, '_step_count': 232, '_get_lr_called_within_step': False, '_last_lr': [9.811376736368592e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 232, '_step_count': 233, '_get_lr_called_within_step': False, '_last_lr': [9.713262969004906e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 233, '_step_count': 234, '_get_lr_called_within_step': False, '_last_lr': [9.616130339314856e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 234, '_step_count': 235, '_get_lr_called_within_step': False, '_last_lr': [9.519969035921707e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 235, '_step_count': 236, '_get_lr_called_within_step': False, '_last_lr': [9.42476934556249e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 236, '_step_count': 237, '_get_lr_called_within_step': False, '_last_lr': [9.330521652106865e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 237, '_step_count': 238, '_get_lr_called_within_step': False, '_last_lr': [9.237216435585796e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 238, '_step_count': 239, '_get_lr_called_within_step': False, '_last_lr': [9.144844271229938e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 239, '_step_count': 240, '_get_lr_called_within_step': False, '_last_lr': [9.053395828517639e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 240, '_step_count': 241, '_get_lr_called_within_step': False, '_last_lr': [8.962861870232463e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 241, '_step_count': 242, '_get_lr_called_within_step': False, '_last_lr': [8.873233251530139e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 242, '_step_count': 243, '_get_lr_called_within_step': False, '_last_lr': [8.784500919014837e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 243, '_step_count': 244, '_get_lr_called_within_step': False, '_last_lr': [8.696655909824688e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 244, '_step_count': 245, '_get_lr_called_within_step': False, '_last_lr': [8.609689350726441e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 245, '_step_count': 246, '_get_lr_called_within_step': False, '_last_lr': [8.523592457219177e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 246, '_step_count': 247, '_get_lr_called_within_step': False, '_last_lr': [8.438356532646986e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 247, '_step_count': 248, '_get_lr_called_within_step': False, '_last_lr': [8.353972967320516e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 248, '_step_count': 249, '_get_lr_called_within_step': False, '_last_lr': [8.270433237647311e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 249, '_step_count': 250, '_get_lr_called_within_step': False, '_last_lr': [8.187728905270838e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 250, '_step_count': 251, '_get_lr_called_within_step': False, '_last_lr': [8.105851616218128e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 251, '_step_count': 252, '_get_lr_called_within_step': False, '_last_lr': [8.024793100055947e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 252, '_step_count': 253, '_get_lr_called_within_step': False, '_last_lr': [7.944545169055387e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 253, '_step_count': 254, '_get_lr_called_within_step': False, '_last_lr': [7.865099717364833e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 254, '_step_count': 255, '_get_lr_called_within_step': False, '_last_lr': [7.786448720191185e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 255, '_step_count': 256, '_get_lr_called_within_step': False, '_last_lr': [7.708584232989272e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 256, '_step_count': 257, '_get_lr_called_within_step': False, '_last_lr': [7.63149839065938e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 257, '_step_count': 258, '_get_lr_called_within_step': False, '_last_lr': [7.555183406752786e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 258, '_step_count': 259, '_get_lr_called_within_step': False, '_last_lr': [7.479631572685258e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 259, '_step_count': 260, '_get_lr_called_within_step': False, '_last_lr': [7.404835256958406e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 260, '_step_count': 261, '_get_lr_called_within_step': False, '_last_lr': [7.330786904388821e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 261, '_step_count': 262, '_get_lr_called_within_step': False, '_last_lr': [7.257479035344933e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 262, '_step_count': 263, '_get_lr_called_within_step': False, '_last_lr': [7.1849042449914836e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 263, '_step_count': 264, '_get_lr_called_within_step': False, '_last_lr': [7.113055202541569e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 264, '_step_count': 265, '_get_lr_called_within_step': False, '_last_lr': [7.041924650516153e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 265, '_step_count': 266, '_get_lr_called_within_step': False, '_last_lr': [6.971505404010991e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 266, '_step_count': 267, '_get_lr_called_within_step': False, '_last_lr': [6.901790349970881e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 267, '_step_count': 268, '_get_lr_called_within_step': False, '_last_lr': [6.8327724464711725e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 268, '_step_count': 269, '_get_lr_called_within_step': False, '_last_lr': [6.7644447220064605e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 269, '_step_count': 270, '_get_lr_called_within_step': False, '_last_lr': [6.6968002747863955e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 270, '_step_count': 271, '_get_lr_called_within_step': False, '_last_lr': [6.629832272038531e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 271, '_step_count': 272, '_get_lr_called_within_step': False, '_last_lr': [6.563533949318146e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 272, '_step_count': 273, '_get_lr_called_within_step': False, '_last_lr': [6.497898609824964e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 273, '_step_count': 274, '_get_lr_called_within_step': False, '_last_lr': [6.432919623726714e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 274, '_step_count': 275, '_get_lr_called_within_step': False, '_last_lr': [6.3685904274894466e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 275, '_step_count': 276, '_get_lr_called_within_step': False, '_last_lr': [6.304904523214552e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 276, '_step_count': 277, '_get_lr_called_within_step': False, '_last_lr': [6.241855477982406e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 277, '_step_count': 278, '_get_lr_called_within_step': False, '_last_lr': [6.179436923202582e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 278, '_step_count': 279, '_get_lr_called_within_step': False, '_last_lr': [6.117642553970556e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 279, '_step_count': 280, '_get_lr_called_within_step': False, '_last_lr': [6.05646612843085e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 280, '_step_count': 281, '_get_lr_called_within_step': False, '_last_lr': [5.995901467146542e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 281, '_step_count': 282, '_get_lr_called_within_step': False, '_last_lr': [5.935942452475077e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 282, '_step_count': 283, '_get_lr_called_within_step': False, '_last_lr': [5.876583027950326e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 283, '_step_count': 284, '_get_lr_called_within_step': False, '_last_lr': [5.817817197670823e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 284, '_step_count': 285, '_get_lr_called_within_step': False, '_last_lr': [5.759639025694115e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 285, '_step_count': 286, '_get_lr_called_within_step': False, '_last_lr': [5.7020426354371736e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 286, '_step_count': 287, '_get_lr_called_within_step': False, '_last_lr': [5.6450222090828014e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 287, '_step_count': 288, '_get_lr_called_within_step': False, '_last_lr': [5.588571986991973e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 288, '_step_count': 289, '_get_lr_called_within_step': False, '_last_lr': [5.532686267122053e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 289, '_step_count': 290, '_get_lr_called_within_step': False, '_last_lr': [5.477359404450832e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 290, '_step_count': 291, '_get_lr_called_within_step': False, '_last_lr': [5.422585810406324e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 291, '_step_count': 292, '_get_lr_called_within_step': False, '_last_lr': [5.368359952302261e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 292, '_step_count': 293, '_get_lr_called_within_step': False, '_last_lr': [5.314676352779238e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 293, '_step_count': 294, '_get_lr_called_within_step': False, '_last_lr': [5.261529589251446e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 294, '_step_count': 295, '_get_lr_called_within_step': False, '_last_lr': [5.208914293358931e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 295, '_step_count': 296, '_get_lr_called_within_step': False, '_last_lr': [5.156825150425342e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 296, '_step_count': 297, '_get_lr_called_within_step': False, '_last_lr': [5.105256898921088e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 297, '_step_count': 298, '_get_lr_called_within_step': False, '_last_lr': [5.0542043299318774e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 298, '_step_count': 299, '_get_lr_called_within_step': False, '_last_lr': [5.003662286632559e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 299, '_step_count': 300, '_get_lr_called_within_step': False, '_last_lr': [4.9536256637662335e-06]}
# {'gamma': 0.99, 'base_lrs': [0.0001], 'last_epoch': 300, '_step_count': 301, '_get_lr_called_within_step': False, '_last_lr': [4.9040894071285715e-06]}

# %%
data_set.filename_list
# for i in range(1000):
#     scheduler.step()
#     print(scheduler.state_dict())
#     break

# %%
optimizer_my.step()
print(optimizer_my.state_dict())

# %%
import numpy as np
a=np.ones((79,94))
a=np.repeat(a,3,axis=2)
a.shape

# %%
# print(args.cpu)
from PIL import Image
transforms.Resize((target_height,target_width), interpolation=Image.BICUBIC)
a=([])
# pretrained_dict=torch.load('./model/RCAN_BIX4.pt',map_location=torch.device('cpu'))
# model_dict=net.state_dict()
# # 1. filter out unnecessary keys
# pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict}
# # 2. overwrite entries in the existing state dict
# model_dict.update(pretrained_dict)
# net.load_state_dict(model_dict)


# net.to(device).model.sub_mean_my(torch.ones((2,3,79,94)))#-427.2142, 正确

# %%
for batch, (lr,hr,_,_) in enumerate(train_dataloders):
    with torch.no_grad():
        sr=net(lr,4)
        
    break

# %%
torch.max(sr[:,[0]])

# %%
hr.shape

# %%
X = np.random.randint(0,100,(1,5,6))
Xmin = np.min(X)
Xmax = np.max(X)
#将数据映射到[-1,1]区间 即a=-1，b=1
a = -1
b = 1
Y = a + (b-a)/(Xmax-Xmin)*(X-Xmin)

# %%
Y
